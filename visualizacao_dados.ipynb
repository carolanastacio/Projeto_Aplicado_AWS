# %%
import pandas as pd

# %%
# %pip install pyarrow
# Out:
# ...
#    ---------------------------------------- 0.0/25.2 MB ? eta -:--:--
#    - -------------------------------------- 0.8/25.2 MB 4.3 MB/s eta 0:00:06
#    -- ------------------------------------- 1.6/25.2 MB 4.1 MB/s eta 0:00:06
#    ---- ----------------------------------- 2.6/25.2 MB 4.2 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.4/25.2 MB 4.2 MB/s eta 0:00:06
#    ------ --------------------------------- 4.2/25.2 MB 4.2 MB/s eta 0:00:06
#    -------- ------------------------------- 5.2/25.2 MB 4.2 MB/s eta 0:00:05
#    --------- ------------------------------ 6.0/25.2 MB 4.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 7.1/25.2 MB 4.2 MB/s eta 0:00:05
#    ------------ --------------------------- 7.9/25.2 MB 4.2 MB/s eta 0:00:05
#    -------------- ------------------------- 8.9/25.2 MB 4.2 MB/s eta 0:00:04
#    --------------- ------------------------ 9.7/25.2 MB 4.2 MB/s eta 0:00:04
# ...

# %%
# Caminho do arquivo no S3
s3_path = "s3://mybucket-sunctech-silver/run-1744762721521-part-block-0-r-00000-snappy.parquet"

# %%
# Ler arquivo parquet
df = pd.read_parquet(s3_path, engine="pyarrow")

# %%
# Exibir amostra
df.head()
# Out:
#   numordeminterrupcao                          dscfatogeradorinterrupcao  \
# 0              2025-1  INTERNA - NAO PROGRAMADA - PROPRIAS DO SISTEMA...
# 1          2025-25087   INTERNA - NAO PROGRAMADA - MEIO AMBIENTE - VENTO
# 2          2025-16707  INTERNA - NAO PROGRAMADA - PROPRIAS DO SISTEMA...
# 3          2025-27268  INTERNA - NAO PROGRAMADA - MEIO AMBIENTE - ARV...
# 4          2025-16733  INTERNA - NAO PROGRAMADA - PROPRIAS DO SISTEMA...
#
#               sigagente  numunidadeconsumidora dscalimentadorsubestacao  \
# 0  EAC                                       1                     01C4
# 1  EAC                                       0                     01C2
# 2  EAC                                       2                     09S3
# 3  EAC                                     136                     01C1
# 4  EAC                                       1                     01I5
#
#   dsctipointerrupcao datfiminterrupcao dscsubestacaodistribuicao  numano  \
# ...
